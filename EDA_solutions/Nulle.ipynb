# %%
import pandas as pd
data = pd.read_csv('Loan_Default.csv')
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', 100)
data.loc[(data["Upfront_charges"].isnull()) & (data["Status"]== 1)]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 10       24900  2019         cf               Male         nopre     type2
# 12       24902  2019         cf              Joint         nopre     type2
# 15       24905  2019         cf               Male         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148651  173541  2019         cf              Joint         nopre     type3
# 148652  173542  2019         cf               Male         nopre     type1
# 148658  173548  2019         cf  Sex Not Available         nopre     type1
# 148661  173551  2019         cf  Sex Not Available         nopre     type2
# 148663  173553  2019         cf               Male         nopre     type2
#
# ...

# %%
pd.set_option('display.max_rows', 100)
data.loc[(data["Upfront_charges"].isnull()) & (data["Status"]== 1)&(data["rate_of_interest"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 10       24900  2019         cf               Male         nopre     type2
# 12       24902  2019         cf              Joint         nopre     type2
# 15       24905  2019         cf               Male         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148651  173541  2019         cf              Joint         nopre     type3
# 148652  173542  2019         cf               Male         nopre     type1
# 148658  173548  2019         cf  Sex Not Available         nopre     type1
# 148661  173551  2019         cf  Sex Not Available         nopre     type2
# 148663  173553  2019         cf               Male         nopre     type2
#
# ...

# %%
pd.set_option('display.max_rows', 20)
data.loc[(data["Upfront_charges"].isnull()) & (data["Status"]== 1) & (~data["rate_of_interest"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 7205     32095  2019        ncf  Sex Not Available         nopre     type2
# 7216     32106  2019        ncf  Sex Not Available         nopre     type2
# 7263     32153  2019        ncf  Sex Not Available         nopre     type2
# 8053     32943  2019        ncf  Sex Not Available         nopre     type1
# 8862     33752  2019        ncf  Sex Not Available         nopre     type2
# ...        ...   ...        ...                ...           ...       ...
# 115205  140095  2019        ncf  Sex Not Available         nopre     type1
# 115577  140467  2019        NaN  Sex Not Available         nopre     type2
# 118230  143120  2019        NaN  Sex Not Available         nopre     type2
# 119922  144812  2019        ncf  Sex Not Available         nopre     type2
# 132976  157866  2019        ncf  Sex Not Available         nopre     type2
#
# ...

# %%
#Def. błędnej danej w deafaulcie(błedny default): Osoby nie mające null w rate_of_interest i mające status 1,
#mają null w age i w submission_of_application
#Mamy 36639 deafaultow zakładając, że 200 z nich to "blędy w danych", czyli 36439 to "prawdziwe defaulty", oczywiście w teorii
#Widzimy, że default charakteryzuje null w rate_of_interest i Interest_rate_spread
#Zauważamy, że każdy prawdziwy default ma null w upfront_charges, ale niektóre błędne defaulty mają wartość w upfront_charges,
#a niektóre nie mają (153:47)
#Wiec nowy def. prawdziwego defaultu: Osoby mające null w rate_of_interest, Interest_rate_spread, upfront_charges

# %%
#Badamy pozostałe 3156 nulle w braku defaultu (status 0), nie oznacza to 0 wkładu własnego (upfront_charges), bo istnieją wartości 0
pd.set_option('display.max_rows', 40)
data.loc[(data["Upfront_charges"].isnull()) & (data["Status"]== 0)]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 3        24893  2019         cf               Male         nopre     type1
# 59       24949  2019         cf  Sex Not Available           pre     type1
# 68       24958  2019        NaN             Female         nopre     type2
# 82       24972  2019         cf  Sex Not Available         nopre     type1
# 89       24979  2019         cf              Joint         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148380  173270  2019         cf  Sex Not Available         nopre     type2
# 148574  173464  2019         cf  Sex Not Available           pre     type1
# 148585  173475  2019         cf  Sex Not Available         nopre     type1
# 148598  173488  2019         cf              Joint         nopre     type3
# 148628  173518  2019         cf             Female         nopre     type1
#
# ...

# %%
#Wniosek: Nie wiem, bo nic sie chyba nie wyroznia

# %%
#dtir,income,LTV,property_value - badanie nulli

# %%
data.loc[(data["income"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 13       24903  2019         cf              Joint         nopre     type2
# 31       24921  2019         cf               Male         nopre     type3
# 48       24938  2019         cf               Male         nopre     type3
# 87       24977  2019         cf  Sex Not Available           pre     type3
# 96       24986  2019        ncf               Male           pre     type3
# ...        ...   ...        ...                ...           ...       ...
# 148594  173484  2019        ncf              Joint         nopre     type3
# 148598  173488  2019         cf              Joint         nopre     type3
# 148604  173494  2019         cf  Sex Not Available         nopre     type3
# 148646  173536  2019         cf             Female         nopre     type2
# 148661  173551  2019         cf  Sex Not Available         nopre     type2
#
# ...

# %%
data.loc[(data["income"].isnull()) & (~data["dtir1"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 855      25745  2019         cf             Female         nopre     type1
# 921      25811  2019         cf             Female         nopre     type1
# 6458     31348  2019         cf             Female         nopre     type1
# 6785     31675  2019         cf               Male         nopre     type1
# 7825     32715  2019         cf               Male         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 141164  166054  2019         cf               Male         nopre     type1
# 141844  166734  2019         cf               Male         nopre     type1
# 143595  168485  2019         cf             Female         nopre     type1
# 144128  169018  2019         cf             Female         nopre     type1
# 147002  171892  2019         cf  Sex Not Available           pre     type1
#
# ...

# %%
data.loc[(data["Status"]==1) & (data["income"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 96       24986  2019        ncf               Male           pre     type3
# 103      24993  2019         cf               Male         nopre     type2
# 175      25065  2019         cf             Female         nopre     type2
# 266      25156  2019        ncf  Sex Not Available         nopre     type2
# 428      25318  2019        ncf              Joint         nopre     type3
# ...        ...   ...        ...                ...           ...       ...
# 148239  173129  2019        ncf  Sex Not Available         nopre     type2
# 148373  173263  2019        ncf              Joint         nopre     type3
# 148430  173320  2019         cf  Sex Not Available         nopre     type2
# 148646  173536  2019         cf             Female         nopre     type2
# 148661  173551  2019         cf  Sex Not Available         nopre     type2
#
# ...

# %%
#Można to uznać za błąd(te 110 wierszy), bo osoby mające null w income mają wartość w dtir1(debt to income ratio)

# %%
data.loc[(data["LTV"].isnull()) & (~data["property_value"].isnull())]
# Out:
# Empty DataFrame
# Columns: [ID, year, loan_limit, Gender, approv_in_adv, loan_type, loan_purpose, Credit_Worthiness, open_credit, business_or_commercial, loan_amount, rate_of_interest, Interest_rate_spread, Upfront_charges, term, Neg_ammortization, interest_only, lump_sum_payment, property_value, construction_type, occupancy_type, Secured_by, total_units, income, credit_type, Credit_Score, co-applicant_credit_type, age, submission_of_application, LTV, Region, Security_Type, Status, dtir1]
# Index: []

# %%
#Tu poprawne dane, bo osoby mające null w LTV nie mają wartości w property_value

# %%
data.loc[(data["LTV"].isnull()) & (~data["dtir1"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 123808  148698  2019         cf  Sex Not Available         nopre     type1
# 145931  170821  2019         cf             Female         nopre     type1
#
#        loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 123808           p3                l1        nopc                  nob/c
# 145931           p3                l1        nopc                  nob/c
#
#         loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# 123808       476500             4.500                0.1398              NaN
# 145931       146500             4.125                0.4308              NaN
#
#          term Neg_ammortization interest_only lump_sum_payment  \
# 123808  360.0           not_neg       not_int         not_lpsm
# 145931  180.0           not_neg       not_int         not_lpsm
#
#         property_value construction_type occupancy_type Secured_by  \
# ...

# %%
data.loc[(data["Status"]==1) & (data["property_value"].isnull())& (~data["dtir1"].isnull())]
# Out:
# Empty DataFrame
# Columns: [ID, year, loan_limit, Gender, approv_in_adv, loan_type, loan_purpose, Credit_Worthiness, open_credit, business_or_commercial, loan_amount, rate_of_interest, Interest_rate_spread, Upfront_charges, term, Neg_ammortization, interest_only, lump_sum_payment, property_value, construction_type, occupancy_type, Secured_by, total_units, income, credit_type, Credit_Score, co-applicant_credit_type, age, submission_of_application, LTV, Region, Security_Type, Status, dtir1]
# Index: []

# %%
#Każdy null w LTV nie ma wartości w dtir1(oprócz 2, bo nie mają deafaultu),15098-15096=2

# %%
data.loc[(data["income"].isnull()) & (data["dtir1"].isnull())& (data["property_value"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 3636     28526  2019         cf              Joint         nopre     type1
# 7124     32014  2019         cf  Sex Not Available           pre     type1
# 31163    56053  2019         cf               Male         nopre     type3
# 33043    57933  2019         cf  Sex Not Available           pre     type2
# 33950    58840  2019         cf              Joint         nopre     type1
# 53314    78204  2019         cf  Sex Not Available         nopre     type3
# 54814    79704  2019         cf  Sex Not Available         nopre     type1
# 58448    83338  2019         cf  Sex Not Available         nopre     type2
# 61719    86609  2019         cf             Female         nopre     type2
# 62350    87240  2019         cf  Sex Not Available         nopre     type3
# 86935   111825  2019         cf  Sex Not Available         nopre     type1
# ...

# %%
data.loc[(data["income"].isnull()) & (data["dtir1"].isnull())& (data["property_value"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 3636     28526  2019         cf              Joint         nopre     type1
# 7124     32014  2019         cf  Sex Not Available           pre     type1
# 31163    56053  2019         cf               Male         nopre     type3
# 33043    57933  2019         cf  Sex Not Available           pre     type2
# 33950    58840  2019         cf              Joint         nopre     type1
# 53314    78204  2019         cf  Sex Not Available         nopre     type3
# 54814    79704  2019         cf  Sex Not Available         nopre     type1
# 58448    83338  2019         cf  Sex Not Available         nopre     type2
# 61719    86609  2019         cf             Female         nopre     type2
# 62350    87240  2019         cf  Sex Not Available         nopre     type3
# 86935   111825  2019         cf  Sex Not Available         nopre     type1
# ...

# %%
#są nulle w income, dtir1, property_value i w LTV

# %%
data.loc[(data["income"].isnull()) & (~data["dtir1"].isnull())& (data["property_value"].isnull())]
# Out:
# Empty DataFrame
# Columns: [ID, year, loan_limit, Gender, approv_in_adv, loan_type, loan_purpose, Credit_Worthiness, open_credit, business_or_commercial, loan_amount, rate_of_interest, Interest_rate_spread, Upfront_charges, term, Neg_ammortization, interest_only, lump_sum_payment, property_value, construction_type, occupancy_type, Secured_by, total_units, income, credit_type, Credit_Score, co-applicant_credit_type, age, submission_of_application, LTV, Region, Security_Type, Status, dtir1]
# Index: []

# %%
#dtir1 jest nullem<=>income jest nullem i/lub property_value jest nullem(czyli LTV również nullem)

# %%
data.loc[(data["loan_limit"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 7        24897  2019        NaN             Female         nopre     type1
# 25       24915  2019        NaN              Joint         nopre     type1
# 32       24922  2019        NaN               Male         nopre     type1
# 68       24958  2019        NaN             Female         nopre     type2
# 97       24987  2019        NaN  Sex Not Available         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148409  173299  2019        NaN               Male         nopre     type1
# 148453  173343  2019        NaN               Male         nopre     type1
# 148458  173348  2019        NaN               Male         nopre     type3
# 148467  173357  2019        NaN              Joint         nopre     type1
# 148514  173404  2019        NaN  Sex Not Available         nopre     type1
#
# ...

# %%
#loan_limit_null==3334
data.loc[(data["loan_limit"].isnull()) & (data["approv_in_adv"]== "pre")]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 2535     27425  2019        NaN              Joint           pre     type2
# 4113     29003  2019        NaN               Male           pre     type1
# 11798    36688  2019        NaN  Sex Not Available           pre     type1
# 11801    36691  2019        NaN  Sex Not Available           pre     type1
# 12669    37559  2019        NaN  Sex Not Available           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 142934  167824  2019        NaN               Male           pre     type1
# 143877  168767  2019        NaN  Sex Not Available           pre     type1
# 144224  169114  2019        NaN  Sex Not Available           pre     type1
# 145186  170076  2019        NaN             Female           pre     type1
# 146045  170935  2019        NaN  Sex Not Available           pre     type1
#
# ...

# %%
data.value_counts("approv_in_adv")
# Out:
# approv_in_adv
# nopre    124621
# pre       23141
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', 15)
data.loc[(data["loan_purpose"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 3522     28412  2019         cf               Male         nopre     type1
# 3765     28655  2019        ncf               Male           pre     type1
# 6292     31182  2019        ncf              Joint         nopre     type3
# 7127     32017  2019         cf               Male         nopre     type1
# 9620     34510  2019         cf  Sex Not Available           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 147157  172047  2019        ncf              Joint         nopre     type1
# 147799  172689  2019        ncf  Sex Not Available         nopre     type2
# 147842  172732  2019         cf             Female         nopre     type2
# 148233  173123  2019         cf              Joint           pre     type1
# 148407  173297  2019         cf              Joint           pre     type1
#
# ...

# %%
data.value_counts("Credit_Worthiness")
# Out:
# Credit_Worthiness
# l1    142344
# l2      6326
# Name: count, dtype: int64

# %%
data.value_counts("open_credit")
# Out:
# open_credit
# nopc    148114
# opc        556
# Name: count, dtype: int64

# %%
data.value_counts("interest_only")
# Out:
# interest_only
# not_int     141560
# int_only      7110
# Name: count, dtype: int64

# %%
data.value_counts("construction_type")
# Out:
# construction_type
# sb    148637
# mh        33
# Name: count, dtype: int64

# %%
data.value_counts("Secured_by")
# Out:
# Secured_by
# home    148637
# land        33
# Name: count, dtype: int64

# %%
data.value_counts("lump_sum_payment")
# Out:
# lump_sum_payment
# not_lpsm    145286
# lpsm          3384
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', 15)
data.loc[(data["construction_type"]=="mh") & (data["Secured_by"]=="land")]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 7973     32863  2019         cf              Joint         nopre     type1
# 32312    57202  2019         cf  Sex Not Available         nopre     type1
# 34412    59302  2019         cf             Female         nopre     type1
# 35368    60258  2019         cf  Sex Not Available         nopre     type3
# 36155    61045  2019         cf               Male         nopre     type2
# ...        ...   ...        ...                ...           ...       ...
# 125783  150673  2019         cf  Sex Not Available         nopre     type2
# 128515  153405  2019         cf               Male         nopre     type2
# 140486  165376  2019         cf             Female         nopre     type1
# 146525  171415  2019         cf             Female         nopre     type1
# 148023  172913  2019         cf               Male         nopre     type1
#
# ...

# %%
#Wniosek:
#jeśli construction_type=="mh"(manufactured home) to Secured_by=="land"
#jeśli construction_type=="sb"(site built) to Secured_by=="home"

# %%
pd.set_option('display.max_rows', 50)
data.loc[(data["term"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 1187     26077  2019         cf               Male         nopre     type1
# 2228     27118  2019         cf  Sex Not Available         nopre     type1
# 4373     29263  2019         cf  Sex Not Available         nopre     type1
# 4630     29520  2019         cf               Male         nopre     type1
# 6087     30977  2019         cf               Male         nopre     type1
# 15166    40056  2019         cf             Female         nopre     type1
# 17247    42137  2019         cf              Joint         nopre     type1
# 18443    43333  2019         cf  Sex Not Available         nopre     type1
# 19104    43994  2019         cf  Sex Not Available         nopre     type1
# 28177    53067  2019         cf              Joint         nopre     type1
# 28250    53140  2019         cf             Female         nopre     type1
# ...

# %%
data.value_counts("Neg_ammortization")
#Jeśli term="null" to Neg_ammortization jest negatywne co nie jest typowe
# Out:
# Neg_ammortization
# not_neg    133420
# neg_amm     15129
# Name: count, dtype: int64

# %%
data.value_counts("Security_Type")
# Out:
# Security_Type
# direct      148637
# Indriect        33
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', 10)
data.loc[(data["Neg_ammortization"].isnull())]
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 2458     27348  2019         cf               Male         nopre     type3
# 4691     29581  2019         cf             Female         nopre     type1
# 5845     30735  2019         cf  Sex Not Available         nopre     type1
# 7452     32342  2019         cf  Sex Not Available         nopre     type1
# 8219     33109  2019        ncf              Joint         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 143376  168266  2019         cf  Sex Not Available         nopre     type1
# 143780  168670  2019         cf  Sex Not Available         nopre     type1
# 145279  170169  2019         cf               Male         nopre     type3
# 146531  171421  2019         cf             Female         nopre     type2
# 147010  171900  2019         cf             Female         nopre     type1
#
# ...

# %%
#Wnioski:
#1.Osoby mające null w rate_of_interest, Interest_rate_spread, upfront_charges to prawdziwe defaulty
#2.Fałszywe defaulty to osoby mające null w age i submission_of_application,nie mające nullu w rate_of_interest tym 
#samym mające null w Interst_rate_spread i czasem w upfront_charges tak jak osoby ze statusem 0(tylko częściej),jest ich 200
#3.Null w LTV jest wtedy i tylko wtedy,gdy(<=>) kiedy występuje null w property_value, co  jest poprawne
#4.Null w property_value jest zawsze <=> kiedy występuje null w dtir1, gdy występuje default,
#5.2 osoby mają null w property_value, wartość w dtir1, one mają 0 w statusie, to jedyne osoby z 0 w statusie i nullem 
#w property_value, może błąd
#5.Osoby mające null w income mają BARDZO CZĘSTO null w dtir1 oprócz 110 przypadków co budzi wątpliwości,
#bo zawsze powinny być nulle, ale przy statusie 0, null w income<=> null w dtir1 
#6.Osoby mające null dtir1 zawsze mają null w property_value lub w income lub w obu
#7.Jeśli term="null" to Neg_ammortization jest negatywne co nie jest typowe

#Nienullowe:
#jeśli construction_type=="mh"(manufactured home) to Secured_by=="land"
#jeśli construction_type=="sb"(site built) to Secured_by=="home"

#Pytania:
#1.O czym świadczą nulle w "loan_limit", "loan_purpose", "term", "Neg_ammortization"?
#2.Czemu jest tak duży związek nulla w property_value z nullami w dtir1?\
#3.O czym świadczą nulle w "Upfront_charges" w statusie 0?
